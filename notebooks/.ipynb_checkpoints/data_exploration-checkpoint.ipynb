# %%
from pathlib import Path

BASE_DIR = Path.cwd().parent
DB_PATH = BASE_DIR / "inventorydb.db"

import sqlite3
conn = sqlite3.connect(DB_PATH)

# %%
import pandas as pd

tables = pd.read_sql_query("SELECT name FROM sqlite_master WHERE type='table'", conn)

for table in tables['name']:
    print('Table name', table)
    df = pd.read_sql_query(f"SELECT * from {table} limit 5", conn)
    display(df)
# Out:
# Table name purchase_prices
#                            brand    description  price    size  volume  \
# 0                 Rogers-Sanchez    Yet Product  21.80   Large     750
# 1  Cannon, Reynolds and Alvarado   Lose Product   7.87  Medium    1000
# 2                    Hopkins Ltd  Today Product  80.46   Small     500
# 3       Briggs, Morris and Weber   Life Product  32.94   Small     500
# 4                     Hansen Inc   Note Product  24.63   Small     500
#
#   classification  purchaseprice  vendornumber               vendorname
# 0              C          23.46          1096  White, Miller and Woods
# 1              A          40.75          1058              Watkins Inc
# 2              B          67.15          1030   Lin, Hamilton and Cole
# 3              B          70.17          1050            Christian Ltd
# 4              B          55.46          1061             Miles-Vargas
# Table name purchases
# ...

# %% [markdown]
# | Table | Description |
# | --- | --- |
# | purchase_prices | Product catalog with vendor mapping |
# | purchases | Line-level purchase transactions |
# | vendor_invoice | Aggregated invoices per PO |
# | begin_inventory / end_inventory | Inventory snapshots |

# %%
# Loading tables
purchases = pd.read_sql("SELECT * FROM purchases", conn)
purchase_prices = pd.read_sql("SELECT * FROM purchase_prices", conn)
vendor_invoice = pd.read_sql("SELECT * FROM vendor_invoice", conn)
begin_inventory = pd.read_sql("SELECT * FROM begin_inventory", conn)
end_inventory = pd.read_sql("SELECT * FROM end_inventory", conn)

# %%
purchases.head()
# Out:
#    inventoryid  Store                          Brand    Description    Size  \
# 0            0     42                    Brock Group  Those Product   Small
# 1            1     45                   Wagner Group    Man Product  Medium
# 2            2     21       Massey, Lewis and Walter    Bit Product  Medium
# 3            3      9                     Dawson Inc   Ever Product  Medium
# 4            4      8  Barnes, Pineda and Montgomery  Story Product   Large
#
#    VendorNo               VendorName  PONumber      PODate ReceivingDate  \
# 0      1027             Moss-Jackson     38293  2024-08-15    2024-08-22
# 1      1040         Gregory-Hamilton     45174  2024-10-17    2024-10-26
# 2      1073                 Kent Ltd     88848  2025-03-10    2025-03-17
# 3      1010              Johnson Ltd     10773  2024-12-07    2024-12-14
# 4      1072  Moore, Watts and Nelson     11192  2025-01-01    2025-01-07
#
# ...

# %%
purchases.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 16 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   inventoryid     50000 non-null  int64
#  1   Store           50000 non-null  int64
#  2   Brand           50000 non-null  object
#  3   Description     50000 non-null  object
#  4   Size            50000 non-null  object
#  5   VendorNo        50000 non-null  int64
#  6   VendorName      50000 non-null  object
#  7   PONumber        50000 non-null  int64
#  8   PODate          50000 non-null  object
#  9   ReceivingDate   50000 non-null  object
#  10  InvoiceDate     50000 non-null  object
#  11  PayDate         50000 non-null  object
#  12  PurchasePrice   50000 non-null  float64
#  13  Quantity        50000 non-null  int64
#  14  Dollars         50000 non-null  float64
#  15  Classification  50000 non-null  object
# dtypes: float64(2), int64(5), object(9)
# ...

# %%
# Converting dates
date_cols = ["PODate", "ReceivingDate", "InvoiceDate", "PayDate"]
for col in date_cols:
    purchases[col] = pd.to_datetime(purchases[col])

vendor_invoice["invoicedate"] = pd.to_datetime(vendor_invoice["invoicedate"])
vendor_invoice["podate"] = pd.to_datetime(vendor_invoice["podate"])
vendor_invoice["paydate"] = pd.to_datetime(vendor_invoice["paydate"])

# %%
purchases.isnull().sum()
# Out:
# inventoryid       0
# Store             0
# Brand             0
# Description       0
# Size              0
# VendorNo          0
# VendorName        0
# PONumber          0
# PODate            0
# ReceivingDate     0
# InvoiceDate       0
# PayDate           0
# PurchasePrice     0
# Quantity          0
# Dollars           0
# Classification    0
# dtype: int64

# %% [markdown]
# ### Descriptive Statistics

# %%
purchases.describe()
# Out:
#         inventoryid         Store      VendorNo      PONumber  \
# count  50000.000000  50000.000000  50000.000000  50000.000000
# mean   24999.500000     25.485580   1048.504320  55069.404020
# min        0.000000      1.000000   1000.000000  10000.000000
# 25%    12499.750000     13.000000   1024.000000  32404.000000
# 50%    24999.500000     26.000000   1048.000000  55180.500000
# 75%    37499.250000     38.000000   1072.000000  77759.250000
# max    49999.000000     50.000000   1099.000000  99997.000000
# std    14433.901067     14.432856     28.338437  26028.048508
#
#                            PODate                  ReceivingDate  \
# count                       50000                          50000
# mean   2024-10-04 04:18:27.072000  2024-10-09 16:31:09.120000512
# min           2024-04-06 00:00:00            2024-04-07 00:00:00
# 25%           2024-07-04 00:00:00            2024-07-10 00:00:00
# 50%           2024-10-04 00:00:00            2024-10-09 00:00:00
# ...

# %% [markdown]
# #### Order Value
# - There are a total of 50,000 transactions. The average order value is $2091
# - The mean order value (2091) exceeds the median (1603), indicating presence of high-value purchases (outliers)
# - Std (~1,758) is close to mean, indicating spending is highly inconsistent
#
# #### Quantity
# - The avg quantity is ~ 51 units
# - Quantities are well-balanced (mean and median apx equal)
#
# #### Pricing
# - Wide price range indicates mix of low-cost items and premium products
# - High variability indicates multiple product categories and different vendor pricing tiers
#
# #### Procurement & Payment Timeline
# - Order - Receiving (PODate - ReceivingDate) ≈ ~5 days
# - Fast supply chain (Receiving - Invoice) ≈ ~2–3 days. There are no major delays in supply chain
# - Efficient invoicing process (Invoice - Payment) ≈ ~17–18 days. Payment lag exists. Businesses typically delay payments intentionally
#
# #### Store Distribution
# - Orders are evenly distributed across stores

# %% [markdown]
# ### Relationship btwn quantity, Dollars and Freight
# - Positive correlation:
#     -  `quantity - freight`
#     -   `distance - freight`

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figure(figsize=(4,2))
sns.heatmap(vendor_invoice[['quantity', 'freight']].corr(), annot=True)
plt.show()

# %%
plt.figure(figsize=(4,2))
sns.heatmap(vendor_invoice[['freight', 'vendor_distance']].corr(), annot=True)
plt.show()

# %% [markdown]
# ### Store-Level Analysis

# %%
store_summary = purchases.groupby("Store").agg({
    "Quantity": "sum",
    "Dollars": "sum"
}).reset_index()

store_summary.sort_values("Dollars", ascending=False).head()
# Out:
#     Store  Quantity     Dollars
# 27     28     55293  2328209.13
# 8       9     53519  2253299.95
# 45     46     51154  2243332.23
# 13     14     52665  2212717.89
# 44     45     53379  2202929.46

# %%
plt.bar(store_summary["Store"], store_summary["Dollars"])
plt.title("Revenue by Store")
plt.xlabel("Store")
plt.ylabel("Total Dollars")
plt.show()

# %% [markdown]
# ### Vendor Invoice Analysis

# %%
vendor_invoice.describe()
# Out:
#        vendornumber      ponumber                    invoicedate  \
# count  49846.000000  49846.000000                          49846
# mean    1048.511054  55065.141937  2024-10-12 20:37:32.762508544
# min     1000.000000  10000.000000            2024-04-09 00:00:00
# 25%     1024.000000  32388.000000            2024-07-13 00:00:00
# 50%     1048.000000  55180.000000            2024-10-13 00:00:00
# 75%     1072.000000  77760.750000            2025-01-13 00:00:00
# max     1099.000000  99997.000000            2025-04-20 00:00:00
# std       28.339629  26031.588190                            NaN
#
#                               podate                        paydate  \
# count                          49846                          49846
# mean   2024-10-03 23:51:09.598363136  2024-10-30 07:18:07.814468608
# min              2024-04-06 00:00:00            2024-04-15 00:00:00
# 25%              2024-07-04 00:00:00            2024-07-31 00:00:00
# ...

# %%
vendor_summary = purchases.groupby("VendorName").agg({
    "Quantity": "sum",
    "Dollars": "sum",
    "PONumber": "nunique"
}).reset_index()

vendor_summary.sort_values("Dollars", ascending=False).head()
# Out:
#                   VendorName  Quantity     Dollars  PONumber
# 33              Harrison PLC     70504  2344687.92      1385
# 3                 Banks-King     55589  1996112.39      1105
# 55   Moore, Watts and Nelson     42331  1981337.70       831
# 2                   Ball LLC     47074  1951586.56       917
# 24  Glenn, Hopkins and Davis     45745  1949774.21       906

# %%
plt.scatter(vendor_invoice["quantity"], vendor_invoice["freight"])
plt.xlabel("Quantity")
plt.ylabel("Freight")
plt.title("Freight vs Quantity")
plt.show()

# %% [markdown]
# Freight increases with quantity

# %% [markdown]
# ### Payment & Delay Analysis

# %%
purchases["payment_delay"] = (purchases["PayDate"] - purchases["InvoiceDate"]).dt.days

purchases["payment_delay"].describe()
# Out:
# count    50000.000000
# mean        17.442460
# std          7.490846
# min          5.000000
# 25%         11.000000
# 50%         17.000000
# 75%         24.000000
# max         30.000000
# Name: payment_delay, dtype: float64

# %%
plt.hist(purchases["payment_delay"], bins=30)
plt.title("Payment Delay Distribution")
plt.show()

# %% [markdown]
# ### High spend anomalies

# %%
threshold = purchases["Dollars"].quantile(0.99)

anomalies = purchases[purchases["Dollars"] > threshold]
anomalies.head()
# Out:
#      inventoryid  Store                 Brand      Description    Size  \
# 245          245     47            Quinn-Tran  Whether Product   Large
# 335          335      1  West, Reed and Berry     From Product   Small
# 355          355     12         Davis-Russell   Family Product  Medium
# 442          442      4              Bell Ltd  Address Product  Medium
# 519          519     50              Long Ltd     Area Product   Large
#
#      VendorNo                   VendorName  PONumber     PODate ReceivingDate  \
# 245      1039    Vega, Meyers and Crawford     40250 2024-12-30    2025-01-05
# 335      1031              Watson and Sons     23772 2024-04-26    2024-04-30
# 355      1091   Chen, Peterson and Hawkins     95494 2024-07-12    2024-07-13
# 442      1097  Garrett, Randall and Miller     85072 2025-02-10    2025-02-13
# 519      1069                 Hamilton PLC     20765 2024-12-22    2024-12-25
#
# ...
